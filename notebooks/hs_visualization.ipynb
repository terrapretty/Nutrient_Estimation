# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src import read_data 

folder = "../demo/anacampseros_ex"
output = "../demo/anacampseros_output"

outputs = read_data.main(folder, output)
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  6.60it/s]
# img.shape (512, 640, 141)

# %%
import matplotlib.pyplot as plt

img_idx = 0 # CHANGE ME! CHOOSE IMAGE IDX
ch = 50 # CHANGE ME! CHOOSE WAVELENGTH IDX (FOR BAYSPEC CAMERA: FROM 0 TO 140)

channel = outputs[img_idx][:, :, ch]
plt.imshow(channel, cmap="gray")
plt.show()
